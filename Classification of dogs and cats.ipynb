# %% [markdown]
# <a href="https://colab.research.google.com/github/Arch-suzuki-MB/CNN-in-tensorflow/blob/main/Classification%20of%20dogs%20and%20cats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip" \
    -O "cats-and-dogs.zip"
# Out:
# --2022-12-13 21:46:51--  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip
# Resolving download.microsoft.com (download.microsoft.com)... 104.85.5.10, 2a02:26f0:6d00:39f::317f, 2a02:26f0:6d00:3b6::317f
# Connecting to download.microsoft.com (download.microsoft.com)|104.85.5.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824887076 (787M) [application/octet-stream]
# Saving to: ‘cats-and-dogs.zip’
#
# cats-and-dogs.zip   100%[===================>] 786.67M   111MB/s    in 7.2s
#
# 2022-12-13 21:46:58 (109 MB/s) - ‘cats-and-dogs.zip’ saved [824887076/824887076]

# %%
import tensorflow as tf 
import os
import shutil
import zipfile
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import random
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
zip_ref=zipfile.ZipFile('cats-and-dogs.zip')
zip_ref.extractall('dataset')
zip_ref.close()
dataset=os.path.join('/content/dataset/PetImages')

# %%
folder_path=['/content/train',
             '/content/train/Cat',
             '/content/train/Dog',
             '/content/validation',
             '/content/validation/Cat',
             '/content/validation/Dog']

for path in folder_path :
  if os.path.exists(path)==False:
    os.mkdir(path)

path_train=os.path.join('/content/train')
path_val=os.path.join('/content/validation')

# %%
print('nbre de classe dans le dataset',os.listdir(dataset))
print('le nbre d\'images cats  ',len(os.listdir(dataset+'/Cat')))
print('le nbre d\'images dogs  ',len(os.listdir(dataset+'/Dog')))
# Out:
# nbre de classe dans le dataset ['Cat', 'Dog']
# le nbre d'images cats   12501
# le nbre d'images dogs   12501

# %% [markdown]
# division de dataset sur train et split

# %%
def split_dataset(src_dir=dataset,target_dir=[path_train,path_val],split=0.9):
  class_names=os.listdir(dataset)
  class_names_train=os.listdir(path_train)
  class_names_val=os.listdir(path_val)

  for c in class_names:
    path_class=os.path.join(src_dir+'/'+c)
    img_names=[]
    for name in os.listdir(path_class):
      img_names.append(path_class+'/'+name)
  
    size_class=len(os.listdir(src_dir+'/'+c))
    size_train_split=int(size_class*split)
    print(img_names)
    
    train_img=random.sample(img_names,size_train_split)
    val_img=list(set(img_names)-set(train_img))
    
    for i in train_img:
      target_class=os.path.join(target_dir[0]+'/'+c)
      if(os.path.getsize(i)):
        shutil.copy(i,target_class)
    
    for i in val_img:
      target_class=os.path.join(target_dir[1]+'/'+c)
      if(os.path.getsize(i)):
        shutil.copy(i,target_class)
  return  target_dir

# %%
target_dir=split_dataset()
# Out:
# ['/content/dataset/PetImages/Cat/4713.jpg', '/content/dataset/PetImages/Cat/1823.jpg', '/content/dataset/PetImages/Cat/2955.jpg', '/content/dataset/PetImages/Cat/6417.jpg', '/content/dataset/PetImages/Cat/7113.jpg', '/content/dataset/PetImages/Cat/1177.jpg', '/content/dataset/PetImages/Cat/42.jpg', '/content/dataset/PetImages/Cat/6388.jpg', '/content/dataset/PetImages/Cat/782.jpg', '/content/dataset/PetImages/Cat/9690.jpg', '/content/dataset/PetImages/Cat/11126.jpg', '/content/dataset/PetImages/Cat/8038.jpg', '/content/dataset/PetImages/Cat/3322.jpg', '/content/dataset/PetImages/Cat/9081.jpg', '/content/dataset/PetImages/Cat/4484.jpg', '/content/dataset/PetImages/Cat/7817.jpg', '/content/dataset/PetImages/Cat/7280.jpg', '/content/dataset/PetImages/Cat/11531.jpg', '/content/dataset/PetImages/Cat/9211.jpg', '/content/dataset/PetImages/Cat/11967.jpg', '/content/dataset/PetImages/Cat/2283.jpg', '/content/dataset/PetImages/Cat/9328.jpg', '/content/dataset/PetImages/Cat/11806.jpg', '/content/dataset/PetImages/Cat/2027.jpg', '/content/dataset/PetImages/Cat/3898.jpg', '/content/dataset/PetImages/Cat/4706.jpg', '/content/dataset/PetImages/Cat/7103.jpg', '/content/dataset/PetImages/Cat/3149.jpg', '/content/dataset/PetImages/Cat/7756.jpg', '/content/dataset/PetImages/Cat/10566.jpg', '/content/dataset/PetImages/Cat/6885.jpg', '/content/dataset/PetImages/Cat/395.jpg', '/content/dataset/PetImages/Cat/8160.jpg', '/content/dataset/PetImages/Cat/10531.jpg', '/content/dataset/PetImages/Cat/2228.jpg', '/content/dataset/PetImages/Cat/10985.jpg', '/content/dataset/PetImages/Cat/7634.jpg', '/content/dataset/PetImages/Cat/11417.jpg', '/content/dataset/PetImages/Cat/3860.jpg', '/content/dataset/PetImages/Cat/11207.jpg', '/content/dataset/PetImages/Cat/1867.jpg', '/content/dataset/PetImages/Cat/1444.jpg', '/content/dataset/PetImages/Cat/10153.jpg', '/content/dataset/PetImages/Cat/122.jpg', '/content/dataset/PetImages/Cat/1664.jpg', '/content/dataset/PetImages/Cat/9033.jpg', '/content/dataset/PetImages/Cat/5258.jpg', '/content/dataset/PetImages/Cat/10473.jpg', '/content/dataset/PetImages/Cat/6766.jpg', '/content/dataset/PetImages/Cat/4411.jpg', '/content/dataset/PetImages/Cat/3123.jpg', '/content/dataset/PetImages/Cat/2969.jpg', '/content/dataset/PetImages/Cat/5478.jpg', '/content/dataset/PetImages/Cat/8941.jpg', '/content/dataset/PetImages/Cat/11257.jpg', '/content/dataset/PetImages/Cat/3114.jpg', '/content/dataset/PetImages/Cat/959.jpg', '/content/dataset/PetImages/Cat/4388.jpg', '/content/dataset/PetImages/Cat/8261.jpg', '/content/dataset/PetImages/Cat/5721.jpg', '/content/dataset/PetImages/Cat/617.jpg', '/content/dataset/PetImages/Cat/5454.jpg', '/content/dataset/PetImages/Cat/1365.jpg', '/content/dataset/PetImages/Cat/6094.jpg', '/content/dataset/PetImages/Cat/684.jpg', '/content/dataset/PetImages/Cat/274.jpg', '/content/dataset/PetImages/Cat/9394.jpg', '/content/dataset/PetImages/Cat/10661.jpg', '/content/dataset/PetImages/Cat/6487.jpg', '/content/dataset/PetImages/Cat/11398.jpg', '/content/dataset/PetImages/Cat/9321.jpg', '/content/dataset/PetImages/Cat/3089.jpg', '/content/dataset/PetImages/Cat/5983.jpg', '/content/dataset/PetImages/Cat/6649.jpg', '/content/dataset/PetImages/Cat/12186.jpg', '/content/dataset/PetImages/Cat/4252.jpg', '/content/dataset/PetImages/Cat/8719.jpg', '/content/dataset/PetImages/Cat/604.jpg', '/content/dataset/PetImages/Cat/12.jpg', '/content/dataset/PetImages/Cat/133.jpg', '/content/dataset/PetImages/Cat/8564.jpg', '/content/dataset/PetImages/Cat/8073.jpg', '/content/dataset/PetImages/Cat/5325.jpg', '/content/dataset/PetImages/Cat/2254.jpg', '/content/dataset/PetImages/Cat/3378.jpg', '/content/dataset/PetImages/Cat/11906.jpg', '/content/dataset/PetImages/Cat/12247.jpg', '/content/dataset/PetImages/Cat/3548.jpg', '/content/dataset/PetImages/Cat/8216.jpg', '/content/dataset/PetImages/Cat/2405.jpg', '/content/dataset/PetImages/Cat/3734.jpg', '/content/dataset/PetImages/Cat/9141.jpg', '/content/dataset/PetImages/Cat/10871.j ...
# ['/content/dataset/PetImages/Dog/4713.jpg', '/content/dataset/PetImages/Dog/1823.jpg', '/content/dataset/PetImages/Dog/2955.jpg', '/content/dataset/PetImages/Dog/6417.jpg', '/content/dataset/PetImages/Dog/7113.jpg', '/content/dataset/PetImages/Dog/1177.jpg', '/content/dataset/PetImages/Dog/42.jpg', '/content/dataset/PetImages/Dog/6388.jpg', '/content/dataset/PetImages/Dog/782.jpg', '/content/dataset/PetImages/Dog/9690.jpg', '/content/dataset/PetImages/Dog/11126.jpg', '/content/dataset/PetImages/Dog/8038.jpg', '/content/dataset/PetImages/Dog/3322.jpg', '/content/dataset/PetImages/Dog/9081.jpg', '/content/dataset/PetImages/Dog/4484.jpg', '/content/dataset/PetImages/Dog/7817.jpg', '/content/dataset/PetImages/Dog/7280.jpg', '/content/dataset/PetImages/Dog/11531.jpg', '/content/dataset/PetImages/Dog/9211.jpg', '/content/dataset/PetImages/Dog/11967.jpg', '/content/dataset/PetImages/Dog/2283.jpg', '/content/dataset/PetImages/Dog/9328.jpg', '/content/dataset/PetImages/Dog/11806.jpg', '/content/dataset/PetImages/Dog/2027.jpg', '/content/dataset/PetImages/Dog/3898.jpg', '/content/dataset/PetImages/Dog/4706.jpg', '/content/dataset/PetImages/Dog/7103.jpg', '/content/dataset/PetImages/Dog/3149.jpg', '/content/dataset/PetImages/Dog/7756.jpg', '/content/dataset/PetImages/Dog/10566.jpg', '/content/dataset/PetImages/Dog/6885.jpg', '/content/dataset/PetImages/Dog/395.jpg', '/content/dataset/PetImages/Dog/8160.jpg', '/content/dataset/PetImages/Dog/10531.jpg', '/content/dataset/PetImages/Dog/2228.jpg', '/content/dataset/PetImages/Dog/10985.jpg', '/content/dataset/PetImages/Dog/7634.jpg', '/content/dataset/PetImages/Dog/11417.jpg', '/content/dataset/PetImages/Dog/3860.jpg', '/content/dataset/PetImages/Dog/11207.jpg', '/content/dataset/PetImages/Dog/1867.jpg', '/content/dataset/PetImages/Dog/1444.jpg', '/content/dataset/PetImages/Dog/10153.jpg', '/content/dataset/PetImages/Dog/122.jpg', '/content/dataset/PetImages/Dog/1664.jpg', '/content/dataset/PetImages/Dog/9033.jpg', '/content/dataset/PetImages/Dog/5258.jpg', '/content/dataset/PetImages/Dog/10473.jpg', '/content/dataset/PetImages/Dog/6766.jpg', '/content/dataset/PetImages/Dog/4411.jpg', '/content/dataset/PetImages/Dog/3123.jpg', '/content/dataset/PetImages/Dog/2969.jpg', '/content/dataset/PetImages/Dog/5478.jpg', '/content/dataset/PetImages/Dog/8941.jpg', '/content/dataset/PetImages/Dog/11257.jpg', '/content/dataset/PetImages/Dog/3114.jpg', '/content/dataset/PetImages/Dog/959.jpg', '/content/dataset/PetImages/Dog/4388.jpg', '/content/dataset/PetImages/Dog/8261.jpg', '/content/dataset/PetImages/Dog/5721.jpg', '/content/dataset/PetImages/Dog/617.jpg', '/content/dataset/PetImages/Dog/5454.jpg', '/content/dataset/PetImages/Dog/1365.jpg', '/content/dataset/PetImages/Dog/6094.jpg', '/content/dataset/PetImages/Dog/684.jpg', '/content/dataset/PetImages/Dog/274.jpg', '/content/dataset/PetImages/Dog/9394.jpg', '/content/dataset/PetImages/Dog/10661.jpg', '/content/dataset/PetImages/Dog/6487.jpg', '/content/dataset/PetImages/Dog/11398.jpg', '/content/dataset/PetImages/Dog/9321.jpg', '/content/dataset/PetImages/Dog/3089.jpg', '/content/dataset/PetImages/Dog/5983.jpg', '/content/dataset/PetImages/Dog/6649.jpg', '/content/dataset/PetImages/Dog/12186.jpg', '/content/dataset/PetImages/Dog/4252.jpg', '/content/dataset/PetImages/Dog/8719.jpg', '/content/dataset/PetImages/Dog/604.jpg', '/content/dataset/PetImages/Dog/12.jpg', '/content/dataset/PetImages/Dog/133.jpg', '/content/dataset/PetImages/Dog/8564.jpg', '/content/dataset/PetImages/Dog/8073.jpg', '/content/dataset/PetImages/Dog/5325.jpg', '/content/dataset/PetImages/Dog/2254.jpg', '/content/dataset/PetImages/Dog/3378.jpg', '/content/dataset/PetImages/Dog/11906.jpg', '/content/dataset/PetImages/Dog/12247.jpg', '/content/dataset/PetImages/Dog/3548.jpg', '/content/dataset/PetImages/Dog/8216.jpg', '/content/dataset/PetImages/Dog/2405.jpg', '/content/dataset/PetImages/Dog/3734.jpg', '/content/dataset/PetImages/Dog/9141.jpg', '/content/dataset/PetImages/Dog/10871.j ...

# %%
print('taille de train of cat ',len(os.listdir(target_dir[0]+'/Cat')))
print('taille de train of dog ',len(os.listdir(target_dir[0]+'/Dog')))
print('taille de validation of cat ',len(os.listdir(target_dir[1]+'/Cat')))
print('taille de validation of dog ',len(os.listdir(target_dir[1]+'/Dog')))
# Out:
# taille de train of cat  11249
# taille de train of dog  11249
# taille de validation of cat  1251
# taille de validation of dog  1251

# %%
train,val=target_dir[0],target_dir[1]

class_names=os.listdir(dataset)
cat_names_train=random.sample(os.listdir(path_train+'/Cat'),16)
dog_names_train=random.sample(os.listdir(path_train+'/Dog'),16)


path_cat=[]
for k in cat_names_train: 
  path_cat.append(os.path.join(path_train+'/Cat/'+k))

path_dog=[]
for k in dog_names_train:
  path_dog.append(os.path.join(path_train+'/Dog/'+k))

path=path_cat+path_dog
random.shuffle(path)

plt.figure(figsize=(10,10),dpi=200)
for i ,p in enumerate(path):
  plt.subplot (4,8,i+1)
  img=mpimg.imread(p)
  plt.imshow(img)

plt.show()

# %% [markdown]
# labelisation des photos

# %%
train_gen=ImageDataGenerator(rescale=1/255)
train_generator=train_gen.flow_from_directory(
    target_dir[0],
    batch_size=45,
    class_mode='binary',
    target_size=(150,150))


val_gen=ImageDataGenerator(rescale=1/255)
val_generator=val_gen.flow_from_directory(
    target_dir[1],
    batch_size=16,
    class_mode='binary',
    target_size=(150,150))
# Out:
# Found 22496 images belonging to 2 classes.
# Found 2502 images belonging to 2 classes.

# %%
def design_model():
  model=tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation='relu',input_shape=(150,150,3)),
                                    tf.keras.layers.MaxPooling2D((2,2)),
                                    tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
                                    tf.keras.layers.MaxPooling2D((2,2)),
                                    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
                                    tf.keras.layers.MaxPooling2D((2,2)),

                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(512,activation='relu'),
                                    tf.keras.layers.Dense(1,activation='sigmoid')
  ])
  model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['acc'])
  return model

# %%
model=design_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train the model 
import warnings
warnings.filterwarnings('ignore')
hist = model.fit(
          train_generator,
          validation_data=val_generator,
          epochs=15
          )
# Out:
# Epoch 1/15
# 500/500 [==============================] - 88s 159ms/step - loss: 0.5909 - acc: 0.6836 - val_loss: 0.5027 - val_acc: 0.7546
# Epoch 2/15
# 500/500 [==============================] - 78s 156ms/step - loss: 0.4582 - acc: 0.7863 - val_loss: 0.4568 - val_acc: 0.7834
# Epoch 3/15
# 500/500 [==============================] - 79s 158ms/step - loss: 0.3934 - acc: 0.8240 - val_loss: 0.4177 - val_acc: 0.8038
# Epoch 4/15
# 500/500 [==============================] - 77s 154ms/step - loss: 0.3363 - acc: 0.8524 - val_loss: 0.3801 - val_acc: 0.8373
# Epoch 5/15
# 500/500 [==============================] - 77s 154ms/step - loss: 0.2756 - acc: 0.8817 - val_loss: 0.3799 - val_acc: 0.8293
# Epoch 6/15
# 500/500 [==============================] - 78s 156ms/step - loss: 0.2161 - acc: 0.9115 - val_loss: 0.4130 - val_acc: 0.8425
# Epoch 7/15
# 500/500 [==============================] - 77s 154ms/step - loss: 0.1480 - acc: 0.9421 - val_loss: 0.4715 - val_acc: 0.8293
# Epoch 8/15
# 500/500 [==============================] - 78s 155ms/step - loss: 0.0937 - acc: 0.9644 - val_loss: 0.6096 - val_acc: 0.8365
# Epoch 9/15
# 500/500 [==============================] - 76s 152ms/step - loss: 0.0580 - acc: 0.9796 - val_loss: 0.6160 - val_acc: 0.8409
# Epoch 10/15
# 500/500 [==============================] - 77s 153ms/step - loss: 0.0341 - acc: 0.9884 - val_loss: 0.8360 - val_acc: 0.8149
# Epoch 11/15
# 500/500 [==============================] - 77s 154ms/step - loss: 0.0320 - acc: 0.9898 - val_loss: 0.7978 - val_acc: 0.8213
# Epoch 12/15
# 500/500 [==============================] - 76s 152ms/step - loss: 0.0313 - acc: 0.9895 - val_loss: 0.8696 - val_acc: 0.8265
# Epoch 13/15
# 500/500 [==============================] - 77s 154ms/step - loss: 0.0183 - acc: 0.9939 - val_loss: 0.8260 - val_acc: 0.8321
# Epoch 14/15
# 500/500 [==============================] - 77s 153ms/step - loss: 0.0259 - acc: 0.9917 - val_loss: 0.9564 - val_acc: 0.8373
# Epoch 15/15
# 500/500 [==============================] - 77s 155ms/step - loss: 0.0164 - acc: 0.9951 - val_loss: 1.1026 - val_acc: 0.8153

# %%
model.save('/content/model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.

# %%
epochs=hist.epoch
acc=hist.history['acc']
val_acc=hist.history['val_acc']

loss=hist.history['loss']
val_loss=hist.history['val_loss']

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(epochs,acc,'r')
plt.plot(epochs,val_acc,'b')
plt.title("accuracy graph")
plt.legend("accuracy")

plt.subplot(1,2,2)
plt.plot(epochs,loss,'r')
plt.plot(epochs,val_loss,'b')
plt.legend("loss")
plt.title("loss graph")
# Out:
# Text(0.5, 1.0, 'loss graph')
